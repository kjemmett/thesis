# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0, 10, .1)
n = x.shape[0]

y1 = np.sin(x) + np.sin(.5*x+2) + 1.5*np.sin(2*x+2)
y2 = y1 + .5*np.random.randn(n)

plt.plot(x, y1)
plt.plot(x, y2)

# %%
# ?np.random.randn
